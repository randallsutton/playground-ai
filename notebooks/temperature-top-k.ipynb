# %%
import torch

cuda_is_available = torch.cuda.is_available()

if cuda_is_available:
    print("All good!")
else:
    print("CUDA is NOT available!")
# Out:
# CUDA is NOT available!

# %%
# You can use this prompt or try something else!
prompt = "During the latest presentation OpenAI"
# A good model for this exercise, but feel free to use another model: https://huggingface.co/models?pipeline_tag=text-generation&sort=downloads
model = "openai-community/gpt2-large"

# %%
# Step 1 - Set Up the Text Generation Pipeline

# TODO: Import "pipeline" function
from transformers import pipeline

# TODO: Create a pipeline for text generation, selected model, and "device=0" (to use CUDA)
generator = pipeline(task="text-generation", model=model)
# Out:
# model.safetensors:   0%|          | 0.00/3.25G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Device set to use mps:0

# %%
# Step 2 - Generate text with the default settings

# TODO: Generate text with the selected prompt
# Recommended parameters:
# max_length=100 - generate up to 100 tokens
# num_return_sequences=1 - only return one generated sequence
generated_text = generator(prompt, max_length=100, num_return_sequences=1)

print(generated_text[0]["generated_text"])
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=100) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# During the latest presentation OpenAI CEO and cofounder John Goertzel said that they have "no doubt" that they can beat any human. He also says that AI is a "game changer" that will give us "the tools to build super intelligent machines that can do everything from designing cures for diseases to performing surgery."
#
# "The technology is here," he said. "The challenge will be to get people to understand what it means and how to harness it."
#
# Goertzel is optimistic that there will be a "soft takeoff" of AI, meaning that it will take some time for the machine intelligence to catch up with humans.
#
# While the AI industry is still trying to figure out what the future of AI will look like, one thing is for sure: We can't wait to see what the future holds.

# %%
# Step 3 - Experiment with Different Parameters

# Now try different parameters

# TODO: Try text generation with "do_sample" parameter equal to `True` or `False`
generated_text2 = generator(prompt, max_length=100, num_return_sequences=1, do_sample=False)

print(generated_text[0]["generated_text"])
# Out:
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=100) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# During the latest presentation OpenAI CEO and cofounder John Goertzel said that they have "no doubt" that they can beat any human. He also says that AI is a "game changer" that will give us "the tools to build super intelligent machines that can do everything from designing cures for diseases to performing surgery."
#
# "The technology is here," he said. "The challenge will be to get people to understand what it means and how to harness it."
#
# Goertzel is optimistic that there will be a "soft takeoff" of AI, meaning that it will take some time for the machine intelligence to catch up with humans.
#
# While the AI industry is still trying to figure out what the future of AI will look like, one thing is for sure: We can't wait to see what the future holds.

# %%
# TODO: Try text generation using "Beam-search strategy"
# Parameters:
# do_sample=False
# num_beams - try different values
generated_text2 = generator(prompt, max_length=100, num_return_sequences=1, do_sample=False, num_beams=4)

print(generated_text[0]["generated_text"])
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=100) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 5
#       1 # TODO: Try text generation using "Beam-search strategy"
#       2 # Parameters:
#       3 # do_sample=False
#       4 # num_beams - try different values
# ----> 5 generated_text2 = generator(prompt, max_length=100, num_return_sequences=1, do_sample=False, num_beams=4)
#       7 print(generated_text[0]["generated_text"])
#
# File ~/Source/playground-ai/.venv/lib/python3.12/site-packages/transformers/pipelines/text_generation.py:332, in TextGenerationPipeline.__call__(self, text_inputs, **kwargs)
#     330             else:
#     331                 return super().__call__(list(chats), **kwargs)
# --> 332 return super().__call__(text_inputs, **kwargs)
#
# File ~/Source/playground-ai/.venv/lib/python3.12/site-packages/transformers/pipelines/base.py:1467, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1459     return next(
#    1460         iter(
#    1461             self.get_iterator(
#    (...)   1464         )
#    1465     )
#    1466 else:
# -> 1467     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#
# File ~/Source/playground-ai/.venv/lib/python3.12/site-packages/transformers/pipelines/base.py:1474, in Pipeline.run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1472 def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):
#    1473     model_inputs = self.preprocess(inputs, **preprocess_params)
# -> 1474     model_outputs = self.forward(model_inputs, **forward_params)
#    1475     outputs = self.postprocess(model_outputs, **postprocess_params)
#    1476     return outputs
#
# File ~/Source/playground-ai/.venv/lib/python3.12/site-packages/transformers/pipelines/base.py:1374, in Pipeline.forward(self, model_inputs, **forward_params)
#    1372     with inference_context():
#    1373         model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1374         model_outputs = self._forward(model_inputs, **forward_params)
#    1375         model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1376 else:
#
# File ~/Source/playground-ai/.venv/lib/python3.12/site-packages/transformers/pipelines/text_generation.py:432, in TextGenerationPipeline._forward(self, model_inputs, **generate_kwargs)
#     429 if "generation_config" not in generate_kwargs:
#     430     generate_kwargs["generation_config"] = self.generation_config
# --> 432 output = self.model.generate(input_ids=input_ids, attention_mask=attention_mask, **generate_kwargs)
#     434 if isinstance(output, ModelOutput):
#     435     generated_sequence = output.sequences
#
# File ~/Source/playground-ai/.venv/lib/python3.12/site-packages/torch/utils/_contextlib.py:120, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     117 @functools.wraps(func)
#     118 def decorate_context(*args, **kwargs):
#     119     with ctx_factory():
# --> 120         return func(*args, **kwargs)
#
# File ~/Source/playground-ai/.venv/lib/python3.12/site-packages/transformers/generation/utils.py:2564, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, use_model_defaults, custom_generate, **kwargs)
#    2561 model_kwargs["use_cache"] = generation_config.use_cache
#    2563 # 9. Call generation mode
# -> 2564 result = decoding_method(
#    2565     self,
#    2566     input_ids,
#    2567     logits_processor=prepared_logits_processor,
#    2568     stopping_criteria=prepared_stopping_criteria,
#    2569     generation_config=generation_config,
#    2570     **generation_mode_kwargs,
#    2571     **model_kwargs,
#    2572 )
#    2574 # Convert to legacy cache format if requested
#    2575 if (
#    2576     generation_config.return_legacy_cache is True
#    2577     and hasattr(result, "past_key_values")
#    2578     and getattr(result.past_key_values, "to_legacy_cache") is not None
#    2579 ):
#
# File ~/Source/playground-ai/.venv/lib/python3.12/site-packages/transformers/generation/utils.py:3265, in GenerationMixin._beam_search(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, **model_kwargs)
#    3262 flat_running_sequences = self._flatten_beam_dim(running_sequences[:, :, :cur_len])
#    3263 model_inputs = self.prepare_inputs_for_generation(flat_running_sequences, **model_kwargs)
# -> 3265 model_outputs = self(**model_inputs, return_dict=True)
#    3267 # synced_gpus: don't waste resources running the code we don't need; kwargs must be updated before skipping
#    3268 model_kwargs = self._update_model_kwargs_for_generation(
#    3269     model_outputs,
#    3270     model_kwargs,
#    3271     is_encoder_decoder=self.config.is_encoder_decoder,
#    3272 )
#
# File ~/Source/playground-ai/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/Source/playground-ai/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/Source/playground-ai/.venv/lib/python3.12/site-packages/transformers/models/gpt2/modeling_gpt2.py:1068, in GPT2LMHeadModel.forward(self, input_ids, past_key_values, cache_position, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, labels, use_cache, output_attentions, output_hidden_states, return_dict, logits_to_keep, **kwargs)
#    1048 r"""
#    1049 input_ids (`torch.LongTensor` of shape `(batch_size, input_ids_length)`):
#    1050     `input_ids_length` = `sequence_length` if `past_key_values` is `None` else
#    (...)   1064     are ignored (masked), the loss is only computed for labels in `[0, ..., config.vocab_size]`
#    1065 """
#    1066 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# -> 1068 transformer_outputs = self.transformer(
#    1069     input_ids,
#    1070     past_key_values=past_key_values,
#    1071     attention_mask=attention_mask,
#    1072     cache_position=cache_position,
#    1073     token_type_ids=token_type_ids,
#    1074     position_ids=position_ids,
#    1075     head_mask=head_mask,
#    1076     inputs_embeds=inputs_embeds,
#    1077     encoder_hidden_states=encoder_hidden_states,
#    1078     encoder_attention_mask=encoder_attention_mask,
#    1079     use_cache=use_cache,
#    1080     output_attentions=output_attentions,
#    1081     output_hidden_states=output_hidden_states,
#    1082     return_dict=return_dict,
#    1083 )
#    1084 hidden_states = transformer_outputs[0]
#    1086 # Set device for model parallelism
#
# File ~/Source/playground-ai/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/Source/playground-ai/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/Source/playground-ai/.venv/lib/python3.12/site-packages/transformers/models/gpt2/modeling_gpt2.py:925, in GPT2Model.forward(self, input_ids, past_key_values, cache_position, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, use_cache, output_attentions, output_hidden_states, return_dict, **kwargs)
#     922 if output_hidden_states:
#     923     all_hidden_states = all_hidden_states + (hidden_states,)
# --> 925 outputs = block(
#     926     hidden_states,
#     927     past_key_values if not (self.gradient_checkpointing and self.training) else None,
#     928     cache_position,
#     929     causal_mask,
#     930     head_mask[i],
#     931     encoder_hidden_states,  # as a positional argument for gradient checkpointing
#     932     encoder_attention_mask=encoder_attention_mask,
#     933     use_cache=use_cache,
#     934     output_attentions=output_attentions,
#     935     **kwargs,
#     936 )
#     938 hidden_states = outputs[0]
#     940 if output_attentions:
#
# File ~/Source/playground-ai/.venv/lib/python3.12/site-packages/transformers/modeling_layers.py:94, in GradientCheckpointingLayer.__call__(self, *args, **kwargs)
#      91         logger.warning_once(message)
#      93     return self._gradient_checkpointing_func(partial(super().__call__, **kwargs), *args)
# ---> 94 return super().__call__(*args, **kwargs)
#
# File ~/Source/playground-ai/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/Source/playground-ai/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/Source/playground-ai/.venv/lib/python3.12/site-packages/transformers/utils/deprecation.py:172, in deprecate_kwarg.<locals>.wrapper.<locals>.wrapped_func(*args, **kwargs)
#     168 elif minimum_action in (Action.NOTIFY, Action.NOTIFY_ALWAYS) and not is_torchdynamo_compiling():
#     169     # DeprecationWarning is ignored by default, so we use FutureWarning instead
#     170     warnings.warn(message, FutureWarning, stacklevel=2)
# --> 172 return func(*args, **kwargs)
#
# File ~/Source/playground-ai/.venv/lib/python3.12/site-packages/transformers/models/gpt2/modeling_gpt2.py:413, in GPT2Block.forward(self, hidden_states, past_key_values, cache_position, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, use_cache, output_attentions, **kwargs)
#     411 residual = hidden_states
#     412 hidden_states = self.ln_1(hidden_states)
# --> 413 attn_output, self_attn_weights = self.attn(
#     414     hidden_states,
#     415     past_key_values=past_key_values,
#     416     cache_position=cache_position,
#     417     attention_mask=attention_mask,
#     418     head_mask=head_mask,
#     419     use_cache=use_cache,
#     420     output_attentions=output_attentions,
#     421     **kwargs,
#     422 )
#     423 # residual connection
#     424 hidden_states = attn_output + residual
#
# File ~/Source/playground-ai/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/Source/playground-ai/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/Source/playground-ai/.venv/lib/python3.12/site-packages/transformers/utils/deprecation.py:172, in deprecate_kwarg.<locals>.wrapper.<locals>.wrapped_func(*args, **kwargs)
#     168 elif minimum_action in (Action.NOTIFY, Action.NOTIFY_ALWAYS) and not is_torchdynamo_compiling():
#     169     # DeprecationWarning is ignored by default, so we use FutureWarning instead
#     170     warnings.warn(message, FutureWarning, stacklevel=2)
# --> 172 return func(*args, **kwargs)
#
# File ~/Source/playground-ai/.venv/lib/python3.12/site-packages/transformers/models/gpt2/modeling_gpt2.py:358, in GPT2Attention.forward(self, hidden_states, past_key_values, cache_position, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, output_attentions, **kwargs)
#     345     attn_output, attn_weights = attention_interface(
#     346         self,
#     347         query_states,
#    (...)    354         **kwargs,
#     355     )
#     357 attn_output = attn_output.reshape(*attn_output.shape[:-2], -1).contiguous()
# --> 358 attn_output = self.c_proj(attn_output)
#     359 attn_output = self.resid_dropout(attn_output)
#     361 return attn_output, attn_weights
#
# File ~/Source/playground-ai/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/Source/playground-ai/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/Source/playground-ai/.venv/lib/python3.12/site-packages/transformers/pytorch_utils.py:122, in Conv1D.forward(self, x)
#     120 def forward(self, x):
#     121     size_out = x.size()[:-1] + (self.nf,)
# --> 122     x = torch.addmm(self.bias, x.view(-1, x.size(-1)), self.weight)
#     123     x = x.view(size_out)
#     124     return x
#
# KeyboardInterrupt:
